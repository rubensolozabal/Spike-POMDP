# %%
# Read pandas csv

import pandas as pd

df_snn_rnn_oa_Wa = pd.read_csv('../logs/pomdp/Pendulum/V/sac_snn-rnn-memory/gamma-0.9/len--1/bs-32/freq-1.0/oar/09-22:18-27:36.98/progress.csv') 
df_snn_rnn_oa_Wb = pd.read_csv('../logs/pomdp/Pendulum/V/sac_snn-rnn-memory/gamma-0.9/len--1/bs-32/freq-1.0/oar/09-22:18-25:50.90/progress.csv')
df_snn_rnn_oa_Wab = pd.read_csv('../logs/pomdp/Pendulum/V/sac_snn-rnn-memory/gamma-0.9/len--1/bs-32/freq-1.0/oar/09-22:18-26:18.38/progress.csv')
df_snn_rnn_oa_a05 = pd.read_csv('../logs/pomdp/Pendulum/V/sac_snn-rnn-memory/gamma-0.9/len--1/bs-32/freq-1.0/oar/09-22:09-00:18.67/progress.csv')
df_snn_rnn_oa_a09 = pd.read_csv('../logs/pomdp/Pendulum/V/sac_snn-rnn-memory/gamma-0.9/len--1/bs-32/freq-1.0/oar/09-22:08-54:28.16/progress.csv')
df_snn_rnn_oar_Wa = pd.read_csv('../logs/pomdp/Pendulum/V/sac_snn-rnn-memory/gamma-0.9/len--1/bs-32/freq-1.0/oar/09-19:05-41:52.24/progress.csv')

# %%
df_snn_rnn_oa_Wa
# Out:
#      rl_loss/qf1_loss  rl_loss/qf2_loss  rl_loss/policy_loss  \
# 0             10.6326           10.7919               4.4848
# 1              0.2428            0.2480               8.2840
# 2              0.2467            0.2521              12.1968
# 3              0.3036            0.3084              16.3908
# 4              0.4467            0.4490              20.5298
# ..                ...               ...                  ...
# 295            2.2153            2.2576              29.5520
# 296            2.2936            2.3340              29.3935
# 297            2.2377            2.2771              29.4302
# 298            2.3380            2.3953              29.2463
# 299               NaN               NaN                  NaN
#
#      rl_loss/policy_entropy  rl_loss/alpha  rl_loss/q_grad_norm  \
# 0                    0.6804         0.9707               3.1764
# 1                    0.6820         0.9155               5.7692
# ...

# %%
# Delete all lines with NaN in metrics/return_eval_total

df_snn_rnn_oa_Wa = df_snn_rnn_oa_Wa.dropna(subset=['metrics/return_eval_total'])
df_snn_rnn_oa_Wb = df_snn_rnn_oa_Wb.dropna(subset=['metrics/return_eval_total'])
df_snn_rnn_oa_Wab = df_snn_rnn_oa_Wab.dropna(subset=['metrics/return_eval_total'])
df_snn_rnn_oa_a05 = df_snn_rnn_oa_a05.dropna(subset=['metrics/return_eval_total'])
df_snn_rnn_oa_a09 = df_snn_rnn_oa_a09.dropna(subset=['metrics/return_eval_total'])
df_snn_rnn_oar_Wa = df_snn_rnn_oar_Wa.dropna(subset=['metrics/return_eval_total'])

# %%
# Plot using matplotlib

import matplotlib.pyplot as plt

plt.plot(df_snn_rnn_oa_Wa['z/rl_steps'],df_snn_rnn_oa_Wa['metrics/return_eval_total'],  label='snn-rnn_oa_Wa')
plt.plot(df_snn_rnn_oa_Wb['z/rl_steps'],df_snn_rnn_oa_Wb['metrics/return_eval_total'], label='snn-rnn_oa_Wb')
plt.plot(df_snn_rnn_oa_Wab['z/rl_steps'],df_snn_rnn_oa_Wab['metrics/return_eval_total'], label='snn-rnn_oa_Wab')
plt.plot(df_snn_rnn_oa_a05['z/rl_steps'],df_snn_rnn_oa_a05['metrics/return_eval_total'], label='snn-rnn_oa_a05')
plt.plot(df_snn_rnn_oa_a09['z/rl_steps'],df_snn_rnn_oa_a09['metrics/return_eval_total'], label='snn-rnn_oa_a09')
plt.plot(df_snn_rnn_oar_Wa['z/rl_steps'],df_snn_rnn_oar_Wa['metrics/return_eval_total'], label='snn-rnn_oar_Wa')

# Add grid
plt.grid(True)

plt.legend()
